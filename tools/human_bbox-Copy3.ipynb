# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from tqdm import tqdm

import _init_paths
from model.config import cfg
from model.test import im_detect
from model.nms_wrapper import nms
from nets.vgg16 import vgg16
from nets.resnet_v1 import resnetv1
from utils.timer import Timer

# %matplotlib inline

# %%
NETS = {
    'vgg16': ('vgg16_faster_rcnn_iter_%d.pth',),
    'res101': ('res101_faster_rcnn_iter_%d.pth',),
}

DATASETS= {
    'pascal_voc': ('voc_2007_trainval',),
    'pascal_voc_0712': ('voc_2007_trainval+voc_2012_trainval',),
}

IMAGE_DIRECTORY = 'frames/gangnam'
SAVE_DIRECTORY = 'output/gangnam'

torch.set_num_threads(1)
#IMAGE_DIRECTORY = 'demo'

# %%
def vis_detections(im, class_name, dets, thresh=0.5, save_fig=False, fname=None):
    """Draw detected bounding boxes."""
    inds = np.where(dets[:, -1] >= thresh)[0]

    im = im[:, :, (2, 1, 0)]
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.imshow(im, aspect='equal')
    for i in inds:
        bbox = dets[i, :4]
        score = dets[i, -1]

        ax.add_patch(
            plt.Rectangle((bbox[0], bbox[1]),
                          bbox[2] - bbox[0],
                          bbox[3] - bbox[1], fill=False,
                          edgecolor='red', linewidth=3.5)
            )
        ax.text(bbox[0], bbox[1] - 2,
                '{:s} {:.3f}'.format(class_name, score),
                bbox=dict(facecolor='blue', alpha=0.5),
                fontsize=14, color='white')
        
    plt.axis('off')
    plt.tight_layout()
    if save_fig:
        save_file = os.path.join(cfg.DATA_DIR, SAVE_DIRECTORY, fname)
        plt.savefig(save_file)
        plt.close()
    else:
        plt.show()

# %%
def detect_person(net, image_name, save_fig=False):
    """Detect object classes in an image using pre-computed object proposals."""

    # Load the demo image
    im_file = os.path.join(cfg.DATA_DIR, IMAGE_DIRECTORY, image_name)
    im = cv2.imread(im_file)

    # Detect all object classes and regress object bounds
    timer = Timer()
    timer.tic()
    scores, boxes = im_detect(net, im)
    timer.toc()
    print('Detection took {:.3f}s for {:d} object proposals'.format(timer.total_time(), boxes.shape[0]))

    # Visualize detections for each class
    conf_thresh = 0.8
    nms_thresh = 0.3
    
    cls_ind = 15
    cls = 'Person'
    cls_boxes = boxes[:, 4*cls_ind:4*(cls_ind + 1)]
    cls_scores = scores[:, cls_ind]
    dets = np.hstack((cls_boxes, cls_scores[:, np.newaxis])).astype(np.float32)
    keep = nms(torch.from_numpy(dets), nms_thresh)
    dets = dets[keep.numpy(), :]
    vis_detections(im, cls, dets, thresh=conf_thresh, save_fig=save_fig, fname=image_name)
    return scores, boxes

# %%
demonet = 'res101' # Network to use [vgg16 res101]
dataset = 'pascal_voc_0712' # Trained dataset [pascal_voc pascal_voc_0712]

cfg.TEST.HAS_RPN = True  # Use RPN for proposals
cfg.TEST.RPN_POST_NMS_TOP_N = 300 # Paper uses 2000 region proposals

# model path
saved_model = os.path.join('../output', demonet, DATASETS[dataset][0], 'default',
                          NETS[demonet][0] %(70000 if dataset == 'pascal_voc' else 110000))


# load network
net = resnetv1(num_layers=101)
net.create_architecture(21, tag='default', anchor_scales=[8, 16, 32])

net.load_state_dict(torch.load(saved_model, map_location=lambda storage, loc: storage))

net.eval()
net._device = 'cpu'
net.to(net._device)

print('Loaded network {:s}'.format(saved_model))
# Out:
# Loaded network ../output/res101/voc_2007_trainval+voc_2012_trainval/default/res101_faster_rcnn_iter_110000.pth

# %%
frame_skip = 12

im_names = sorted(os.listdir(os.path.join(cfg.DATA_DIR, IMAGE_DIRECTORY)))[2::frame_skip]
#im_names = ['004545.jpg']

for im_name in im_names:
    print(im_name)
    scores, boxes = detect_person(net, im_name, save_fig=True)
# Out:
# frame_000003.jpg
# Detection took 17.181s for 300 object proposals
# frame_000015.jpg
# Detection took 24.079s for 300 object proposals
# frame_000027.jpg
# Detection took 31.168s for 300 object proposals
# frame_000039.jpg
# Detection took 30.421s for 300 object proposals
# frame_000051.jpg
# Detection took 32.202s for 300 object proposals
# frame_000063.jpg
# Detection took 29.580s for 283 object proposals
# frame_000075.jpg
# Detection took 26.138s for 225 object proposals
# frame_000087.jpg
# Detection took 24.052s for 212 object proposals
# frame_000099.jpg
# Detection took 24.342s for 205 object proposals
# frame_000111.jpg
# Detection took 29.086s for 267 object proposals
# frame_000123.jpg
# Detection took 29.529s for 268 object proposals
# frame_000135.jpg
# Detection took 17.584s for 120 object proposals
# frame_000147.jpg
# Detection took 21.986s for 165 object proposals
# frame_000159.jpg
# Detection took 19.727s for 142 object proposals
# frame_000171.jpg
# Detection took 17.183s for 114 object proposals
# frame_000183.jpg
# Detection took 16.159s for 104 object proposals
# frame_000195.jpg
# Detection took 17.729s for 121 object proposals
# frame_000207.jpg
# Detection took 19.030s for 135 object proposals
# frame_000219.jpg
# Detection took 17.275s for 119 object proposals
# frame_000231.jpg
# Detection took 17.238s for 115 object proposals
# frame_000243.jpg
# Detection took 16.949s for 107 object proposals
# frame_000255.jpg
# Detection took 17.694s for 121 object proposals
# frame_000267.jpg
# Detection took 18.389s for 118 object proposals
# frame_000279.jpg
# Detection took 28.021s for 248 object proposals
# frame_000291.jpg
# Detection took 34.500s for 300 object proposals
# frame_000303.jpg
# Detection took 32.474s for 300 object proposals
# frame_000315.jpg
# Detection took 31.309s for 300 object proposals
# frame_000327.jpg
# Detection took 32.188s for 300 object proposals
# frame_000339.jpg
# Detection took 35.035s for 300 object proposals
# frame_000351.jpg
# Detection took 32.970s for 300 object proposals
# frame_000363.jpg
# Detection took 32.925s for 300 object proposals
# frame_000375.jpg
# Detection took 31.767s for 300 object proposals
# frame_000387.jpg
# Detection took 31.353s for 300 object proposals
# frame_000399.jpg
# Detection took 31.827s for 300 object proposals
# frame_000411.jpg
# Detection took 31.476s for 300 object proposals
# frame_000423.jpg
# Detection took 31.805s for 300 object proposals
# frame_000435.jpg
# Detection took 31.732s for 300 object proposals
# frame_000447.jpg
# Detection took 32.508s for 300 object proposals
# frame_000459.jpg
# Detection took 32.470s for 300 object proposals
# frame_000471.jpg
# Detection took 32.209s for 300 object proposals
# frame_000483.jpg
# Detection took 32.024s for 300 object proposals
# frame_000495.jpg
# Detection took 32.337s for 300 object proposals
# frame_000507.jpg
# Detection took 32.138s for 300 object proposals
# frame_000519.jpg
# Detection took 33.569s for 300 object proposals
# frame_000531.jpg
# Detection took 34.065s for 300 object proposals
# frame_000543.jpg
# Detection took 33.272s for 300 object proposals
# frame_000555.jpg
# Detection took 33.029s for 300 object proposals
# frame_000567.jpg
# Detection took 32.174s for 300 object proposals
# frame_000579.jpg
# Detection took 33.432s for 300 object proposals
# frame_000591.jpg
# Detection took 32.051s for 300 object proposals
# frame_000603.jpg
# Detection took 32.848s for 300 object proposals
# frame_000615.jpg
# Detection took 34.018s for 300 object proposals
# frame_000627.jpg
# Detection took 32.595s for 300 object proposals
# frame_000639.jpg
# Detection took 34.270s for 300 object proposals
# frame_000651.jpg
# Detection took 31.766s for 286 object proposals
# frame_000663.jpg
# Detection took 31.500s for 294 object proposals
# frame_000675.jpg
# Detection took 31.964s for 300 object proposals
# frame_000687.jpg
# Detection took 31.181s for 300 object proposals
# frame_000699.jpg
# Detection took 30.789s for 300 object proposals
# frame_000711.jpg
# Detection took 30.506s for 300 object proposals
# frame_000723.jpg
# Detection took 30.693s for 300 object proposals
# frame_000735.jpg
# Detection took 30.348s for 300 object proposals
# frame_000747.jpg
# Detection took 30.701s for 300 object proposals
# frame_000759.jpg
# Detection took 31.069s for 300 object proposals
# frame_000771.jpg
# Detection took 30.988s for 300 object proposals
# frame_000783.jpg
# Detection took 30.336s for 300 object proposals
# frame_000795.jpg
# Detection took 31.718s for 300 object proposals
# frame_000807.jpg
# Detection took 31.697s for 300 object proposals
# frame_000819.jpg
# Detection took 31.911s for 300 object proposals
# frame_000831.jpg
# Detection took 30.721s for 300 object proposals
# frame_000843.jpg
# Detection took 30.959s for 300 object proposals
# frame_000855.jpg
# Detection took 30.668s for 300 object proposals
# frame_000867.jpg
# Detection took 30.999s for 300 object proposals
# frame_000879.jpg
# Detection took 31.360s for 300 object proposals
# frame_000891.jpg
# Detection took 31.465s for 300 object proposals
# frame_000903.jpg
# Detection took 31.361s for 300 object proposals
# frame_000915.jpg
# Detection took 30.708s for 300 object proposals
# frame_000927.jpg
# Detection took 31.418s for 300 object proposals
# frame_000939.jpg
# Detection took 31.130s for 300 object proposals
# frame_000951.jpg
# Detection took 31.110s for 300 object proposals
# frame_000963.jpg
# Detection took 30.426s for 300 object proposals
# frame_000975.jpg
# Detection took 31.463s for 300 object proposals
# frame_000987.jpg
# Detection took 31.418s for 300 object proposals
# frame_000999.jpg
# Detection took 31.344s for 300 object proposals
# frame_001011.jpg
# Detection took 30.628s for 300 object proposals
# frame_001023.jpg
# Detection took 31.112s for 300 object proposals
# frame_001035.jpg
# Detection took 30.799s for 300 object proposals
# frame_001047.jpg
# Detection took 30.675s for 300 object proposals
# frame_001059.jpg
# Detection took 30.829s for 300 object proposals
# frame_001071.jpg
# Detection took 31.074s for 300 object proposals
# frame_001083.jpg
# Detection took 31.028s for 300 object proposals
# frame_001095.jpg
# Detection took 30.714s for 300 object proposals
# frame_001107.jpg
# Detection took 30.711s for 300 object proposals
# frame_001119.jpg
# Detection took 30.585s for 300 object proposals
# frame_001131.jpg
# Detection took 30.760s for 300 object proposals
# frame_001143.jpg
# Detection took 30.639s for 300 object proposals
# frame_001155.jpg
# Detection took 31.804s for 300 object proposals
# frame_001167.jpg
# Detection took 30.505s for 297 object proposals
# frame_001179.jpg
# Detection took 31.540s for 300 object proposals
# frame_001191.jpg
# Detection took 31.056s for 300 object proposals
# frame_001203.jpg
# Detection took 31.084s for 300 object proposals
# frame_001215.jpg
# Detection took 31.001s for 300 object proposals
# frame_001227.jpg
# Detection took 31.433s for 300 object proposals
# frame_001239.jpg
# Detection took 30.448s for 300 object proposals
# frame_001251.jpg
# Detection took 31.788s for 300 object proposals
# frame_001263.jpg
# Detection took 31.427s for 300 object proposals
# frame_001275.jpg
# Detection took 31.459s for 300 object proposals
# frame_001287.jpg
# Detection took 30.848s for 300 object proposals
# frame_001299.jpg
# Detection took 31.020s for 300 object proposals
# frame_001311.jpg
# Detection took 31.194s for 300 object proposals
# frame_001323.jpg
# Detection took 30.432s for 300 object proposals
# frame_001335.jpg
# Detection took 30.593s for 300 object proposals
# frame_001347.jpg
# Detection took 31.054s for 300 object proposals
# frame_001359.jpg
# Detection took 31.066s for 300 object proposals
# frame_001371.jpg
# Detection took 30.823s for 300 object proposals
# frame_001383.jpg
# Detection took 30.898s for 300 object proposals
# frame_001395.jpg
# Detection took 30.705s for 300 object proposals
# frame_001407.jpg
# Detection took 31.342s for 300 object proposals
# frame_001419.jpg
# Detection took 25.886s for 224 object proposals
# frame_001431.jpg
# Detection took 30.327s for 287 object proposals
# frame_001443.jpg
# Detection took 31.092s for 298 object proposals
# frame_001455.jpg
# Detection took 31.949s for 300 object proposals
# frame_001467.jpg
# Detection took 31.326s for 300 object proposals
# frame_001479.jpg
# Detection took 31.045s for 300 object proposals
# frame_001491.jpg
# Detection took 31.290s for 300 object proposals
# frame_001503.jpg
# Detection took 32.020s for 300 object proposals
# frame_001515.jpg
# Detection took 31.504s for 300 object proposals
# frame_001527.jpg
# Detection took 30.821s for 300 object proposals
# frame_001539.jpg
# Detection took 31.368s for 300 object proposals
# frame_001551.jpg
# Detection took 30.715s for 300 object proposals
# frame_001563.jpg
# Detection took 30.364s for 300 object proposals
# frame_001575.jpg
# Detection took 30.883s for 300 object proposals
# frame_001587.jpg
# Detection took 30.760s for 300 object proposals
# frame_001599.jpg
# Detection took 31.351s for 300 object proposals
# frame_001611.jpg
# Detection took 31.229s for 300 object proposals
# frame_001623.jpg
# Detection took 33.897s for 300 object proposals
# frame_001635.jpg
# Detection took 33.748s for 300 object proposals
# frame_001647.jpg
# Detection took 37.361s for 300 object proposals
# frame_001659.jpg
# Detection took 36.649s for 300 object proposals
# frame_001671.jpg
# Detection took 32.143s for 300 object proposals
# frame_001683.jpg
# Detection took 29.425s for 264 object proposals
# frame_001695.jpg
# Detection took 23.769s for 188 object proposals
# frame_001707.jpg
# Detection took 29.080s for 300 object proposals
# frame_001719.jpg
# Detection took 31.377s for 300 object proposals
# frame_001731.jpg
# Detection took 30.300s for 300 object proposals
# frame_001743.jpg
# Detection took 28.834s for 300 object proposals
# frame_001755.jpg
# Detection took 24.354s for 300 object proposals
# frame_001767.jpg
# Detection took 28.886s for 300 object proposals
# frame_001779.jpg
# Detection took 26.366s for 300 object proposals
# frame_001791.jpg
# Detection took 27.887s for 300 object proposals
# frame_001803.jpg
# Detection took 23.291s for 300 object proposals
# frame_001815.jpg
# Detection took 25.842s for 300 object proposals
# frame_001827.jpg
# Detection took 26.008s for 300 object proposals
# frame_001839.jpg
# Detection took 26.137s for 300 object proposals
# frame_001851.jpg
# Detection took 25.775s for 300 object proposals
# frame_001863.jpg
# Detection took 30.126s for 300 object proposals
# frame_001875.jpg
# Detection took 28.504s for 300 object proposals
# frame_001887.jpg
# Detection took 21.018s for 300 object proposals
# frame_001899.jpg
# Detection took 27.783s for 300 object proposals
# frame_001911.jpg
# Detection took 25.226s for 300 object proposals
# frame_001923.jpg
# Detection took 25.332s for 300 object proposals
# frame_001935.jpg
# Detection took 24.533s for 300 object proposals
# frame_001947.jpg
# Detection took 22.041s for 300 object proposals
# frame_001959.jpg
# Detection took 23.470s for 300 object proposals
# frame_001971.jpg
# Detection took 29.720s for 300 object proposals
# frame_001983.jpg
# Detection took 21.275s for 300 object proposals
# frame_001995.jpg
# Detection took 25.808s for 300 object proposals
# frame_002007.jpg
# Detection took 27.700s for 300 object proposals
# frame_002019.jpg
# Detection took 24.047s for 300 object proposals
# frame_002031.jpg
# Detection took 26.471s for 300 object proposals
# frame_002043.jpg
# Detection took 23.871s for 300 object proposals
# frame_002055.jpg
# Detection took 23.179s for 300 object proposals
# frame_002067.jpg
# Detection took 24.062s for 300 object proposals
# frame_002079.jpg
# Detection took 25.800s for 300 object proposals
# frame_002091.jpg
# Detection took 28.769s for 300 object proposals
# frame_002103.jpg
# Detection took 31.434s for 300 object proposals
# frame_002115.jpg
# Detection took 27.775s for 300 object proposals
# frame_002127.jpg
