# %%
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from tqdm import tqdm

import _init_paths
from model.config import cfg
from model.test import im_detect
from model.nms_wrapper import nms
from nets.vgg16 import vgg16
from nets.resnet_v1 import resnetv1
from utils.timer import Timer

# %matplotlib inline

# %%
NETS = {
    'vgg16': ('vgg16_faster_rcnn_iter_%d.pth',),
    'res101': ('res101_faster_rcnn_iter_%d.pth',),
}

DATASETS= {
    'pascal_voc': ('voc_2007_trainval',),
    'pascal_voc_0712': ('voc_2007_trainval+voc_2012_trainval',),
}

IMAGE_DIRECTORY = 'frames/gangnam'
SAVE_DIRECTORY = 'output/gangnam'

torch.set_num_threads(1)
#IMAGE_DIRECTORY = 'demo'

# %%
def vis_detections(im, class_name, dets, thresh=0.5, save_fig=False, fname=None):
    """Draw detected bounding boxes."""
    inds = np.where(dets[:, -1] >= thresh)[0]

    im = im[:, :, (2, 1, 0)]
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.imshow(im, aspect='equal')
    for i in inds:
        bbox = dets[i, :4]
        score = dets[i, -1]

        ax.add_patch(
            plt.Rectangle((bbox[0], bbox[1]),
                          bbox[2] - bbox[0],
                          bbox[3] - bbox[1], fill=False,
                          edgecolor='red', linewidth=3.5)
            )
        ax.text(bbox[0], bbox[1] - 2,
                '{:s} {:.3f}'.format(class_name, score),
                bbox=dict(facecolor='blue', alpha=0.5),
                fontsize=14, color='white')
        
    plt.axis('off')
    plt.tight_layout()
    if save_fig:
        save_file = os.path.join(cfg.DATA_DIR, SAVE_DIRECTORY, fname)
        plt.savefig(save_file)
        plt.close()
    else:
        plt.show()

# %%
def detect_person(net, image_name, save_fig=False):
    """Detect object classes in an image using pre-computed object proposals."""

    # Load the demo image
    im_file = os.path.join(cfg.DATA_DIR, IMAGE_DIRECTORY, image_name)
    im = cv2.imread(im_file)

    # Detect all object classes and regress object bounds
    timer = Timer()
    timer.tic()
    scores, boxes = im_detect(net, im)
    timer.toc()
    print('Detection took {:.3f}s for {:d} object proposals'.format(timer.total_time(), boxes.shape[0]))

    # Visualize detections for each class
    conf_thresh = 0.8
    nms_thresh = 0.3
    
    cls_ind = 15
    cls = 'Person'
    cls_boxes = boxes[:, 4*cls_ind:4*(cls_ind + 1)]
    cls_scores = scores[:, cls_ind]
    dets = np.hstack((cls_boxes, cls_scores[:, np.newaxis])).astype(np.float32)
    keep = nms(torch.from_numpy(dets), nms_thresh)
    dets = dets[keep.numpy(), :]
    vis_detections(im, cls, dets, thresh=conf_thresh, save_fig=save_fig, fname=image_name)
    return scores, boxes

# %%
demonet = 'res101' # Network to use [vgg16 res101]
dataset = 'pascal_voc_0712' # Trained dataset [pascal_voc pascal_voc_0712]

cfg.TEST.HAS_RPN = True  # Use RPN for proposals
cfg.TEST.RPN_POST_NMS_TOP_N = 300 # Paper uses 2000 region proposals

# model path
saved_model = os.path.join('../output', demonet, DATASETS[dataset][0], 'default',
                          NETS[demonet][0] %(70000 if dataset == 'pascal_voc' else 110000))


# load network
net = resnetv1(num_layers=101)
net.create_architecture(21, tag='default', anchor_scales=[8, 16, 32])

net.load_state_dict(torch.load(saved_model, map_location=lambda storage, loc: storage))

net.eval()
net._device = 'cpu'
net.to(net._device)

print('Loaded network {:s}'.format(saved_model))
# Out:
# Loaded network ../output/res101/voc_2007_trainval+voc_2012_trainval/default/res101_faster_rcnn_iter_110000.pth

# %%
frame_skip = 12

im_names = sorted(os.listdir(os.path.join(cfg.DATA_DIR, IMAGE_DIRECTORY)))[10::frame_skip]
#im_names = ['004545.jpg']

for im_name in im_names:
    print(im_name)
    scores, boxes = detect_person(net, im_name, save_fig=True)
# Out:
# frame_000011.jpg
# Detection took 32.992s for 300 object proposals
# frame_000023.jpg
# Detection took 31.171s for 300 object proposals
# frame_000035.jpg
# Detection took 31.781s for 300 object proposals
# frame_000047.jpg
# Detection took 33.651s for 300 object proposals
# frame_000059.jpg
# Detection took 31.565s for 292 object proposals
# frame_000071.jpg
# Detection took 28.069s for 240 object proposals
# frame_000083.jpg
# Detection took 26.333s for 220 object proposals
# frame_000095.jpg
# Detection took 25.408s for 209 object proposals
# frame_000107.jpg
# Detection took 28.726s for 265 object proposals
# frame_000119.jpg
# Detection took 30.701s for 278 object proposals
# frame_000131.jpg
# Detection took 31.650s for 300 object proposals
# frame_000143.jpg
# Detection took 21.559s for 155 object proposals
# frame_000155.jpg
# Detection took 19.912s for 136 object proposals
# frame_000167.jpg
# Detection took 17.267s for 104 object proposals
# frame_000179.jpg
# Detection took 17.888s for 109 object proposals
# frame_000191.jpg
# Detection took 17.757s for 118 object proposals
# frame_000203.jpg
# Detection took 17.485s for 121 object proposals
# frame_000215.jpg
# Detection took 18.376s for 117 object proposals
# frame_000227.jpg
# Detection took 17.811s for 111 object proposals
# frame_000239.jpg
# Detection took 18.992s for 122 object proposals
# frame_000251.jpg
# Detection took 16.924s for 113 object proposals
# frame_000263.jpg
# Detection took 18.343s for 116 object proposals
# frame_000275.jpg
# Detection took 29.156s for 247 object proposals
# frame_000287.jpg
# Detection took 27.869s for 250 object proposals
# frame_000299.jpg
# Detection took 32.449s for 300 object proposals
# frame_000311.jpg
# Detection took 34.549s for 300 object proposals
# frame_000323.jpg
# Detection took 33.322s for 300 object proposals
# frame_000335.jpg
# Detection took 32.282s for 300 object proposals
# frame_000347.jpg
# Detection took 34.878s for 300 object proposals
# frame_000359.jpg
# Detection took 32.868s for 300 object proposals
# frame_000371.jpg
# Detection took 33.226s for 300 object proposals
# frame_000383.jpg
# Detection took 32.461s for 300 object proposals
# frame_000395.jpg
# Detection took 32.672s for 300 object proposals
# frame_000407.jpg
# Detection took 32.144s for 300 object proposals
# frame_000419.jpg
# Detection took 32.044s for 300 object proposals
# frame_000431.jpg
# Detection took 32.801s for 300 object proposals
# frame_000443.jpg
# Detection took 32.067s for 300 object proposals
# frame_000455.jpg
# Detection took 32.669s for 300 object proposals
# frame_000467.jpg
# Detection took 32.548s for 300 object proposals
# frame_000479.jpg
# Detection took 32.316s for 300 object proposals
# frame_000491.jpg
# Detection took 31.792s for 300 object proposals
# frame_000503.jpg
# Detection took 31.908s for 300 object proposals
# frame_000515.jpg
# Detection took 31.999s for 300 object proposals
# frame_000527.jpg
# Detection took 32.473s for 300 object proposals
# frame_000539.jpg
# Detection took 32.541s for 300 object proposals
# frame_000551.jpg
# Detection took 32.490s for 300 object proposals
# frame_000563.jpg
# Detection took 33.802s for 300 object proposals
# frame_000575.jpg
# Detection took 33.365s for 300 object proposals
# frame_000587.jpg
# Detection took 32.487s for 300 object proposals
# frame_000599.jpg
# Detection took 32.007s for 300 object proposals
# frame_000611.jpg
# Detection took 31.672s for 300 object proposals
# frame_000623.jpg
# Detection took 32.055s for 300 object proposals
# frame_000635.jpg
# Detection took 31.936s for 300 object proposals
# frame_000647.jpg
# Detection took 32.742s for 300 object proposals
# frame_000659.jpg
# Detection took 29.403s for 273 object proposals
# frame_000671.jpg
# Detection took 31.155s for 300 object proposals
# frame_000683.jpg
# Detection took 31.601s for 300 object proposals
# frame_000695.jpg
# Detection took 31.499s for 300 object proposals
# frame_000707.jpg
# Detection took 30.740s for 300 object proposals
# frame_000719.jpg
# Detection took 30.694s for 300 object proposals
# frame_000731.jpg
# Detection took 30.211s for 300 object proposals
# frame_000743.jpg
# Detection took 30.671s for 300 object proposals
# frame_000755.jpg
# Detection took 30.904s for 300 object proposals
# frame_000767.jpg
# Detection took 30.119s for 300 object proposals
# frame_000779.jpg
# Detection took 30.302s for 300 object proposals
# frame_000791.jpg
# Detection took 30.802s for 300 object proposals
# frame_000803.jpg
# Detection took 30.537s for 300 object proposals
# frame_000815.jpg
# Detection took 31.242s for 300 object proposals
# frame_000827.jpg
# Detection took 30.589s for 300 object proposals
# frame_000839.jpg
# Detection took 30.900s for 300 object proposals
# frame_000851.jpg
# Detection took 31.106s for 300 object proposals
# frame_000863.jpg
# Detection took 30.902s for 300 object proposals
# frame_000875.jpg
# Detection took 30.800s for 300 object proposals
# frame_000887.jpg
# Detection took 30.801s for 300 object proposals
# frame_000899.jpg
# Detection took 30.523s for 300 object proposals
# frame_000911.jpg
# Detection took 30.416s for 300 object proposals
# frame_000923.jpg
# Detection took 30.981s for 300 object proposals
# frame_000935.jpg
# Detection took 31.500s for 300 object proposals
# frame_000947.jpg
# Detection took 30.313s for 300 object proposals
# frame_000959.jpg
# Detection took 30.640s for 300 object proposals
# frame_000971.jpg
# Detection took 29.925s for 300 object proposals
# frame_000983.jpg
# Detection took 30.815s for 300 object proposals
# frame_000995.jpg
# Detection took 30.974s for 300 object proposals
# frame_001007.jpg
# Detection took 30.818s for 300 object proposals
# frame_001019.jpg
# Detection took 30.403s for 300 object proposals
# frame_001031.jpg
# Detection took 31.095s for 300 object proposals
# frame_001043.jpg
# Detection took 30.941s for 300 object proposals
# frame_001055.jpg
# Detection took 30.787s for 300 object proposals
# frame_001067.jpg
# Detection took 30.873s for 300 object proposals
# frame_001079.jpg
# Detection took 30.484s for 300 object proposals
# frame_001091.jpg
# Detection took 30.325s for 300 object proposals
# frame_001103.jpg
# Detection took 30.127s for 300 object proposals
# frame_001115.jpg
# Detection took 25.287s for 240 object proposals
# frame_001127.jpg
# Detection took 31.316s for 300 object proposals
# frame_001139.jpg
# Detection took 30.186s for 300 object proposals
# frame_001151.jpg
# Detection took 29.774s for 297 object proposals
# frame_001163.jpg
# Detection took 30.434s for 300 object proposals
# frame_001175.jpg
# Detection took 30.648s for 300 object proposals
# frame_001187.jpg
# Detection took 30.100s for 300 object proposals
# frame_001199.jpg
# Detection took 30.943s for 300 object proposals
# frame_001211.jpg
# Detection took 29.728s for 300 object proposals
# frame_001223.jpg
# Detection took 30.088s for 300 object proposals
# frame_001235.jpg
# Detection took 30.525s for 300 object proposals
# frame_001247.jpg
# Detection took 30.074s for 300 object proposals
# frame_001259.jpg
# Detection took 29.588s for 300 object proposals
# frame_001271.jpg
# Detection took 29.969s for 300 object proposals
# frame_001283.jpg
# Detection took 30.268s for 300 object proposals
# frame_001295.jpg
# Detection took 30.206s for 300 object proposals
# frame_001307.jpg
# Detection took 29.876s for 300 object proposals
# frame_001319.jpg
# Detection took 30.274s for 300 object proposals
# frame_001331.jpg
# Detection took 29.867s for 300 object proposals
# frame_001343.jpg
# Detection took 29.878s for 300 object proposals
# frame_001355.jpg
# Detection took 30.978s for 300 object proposals
# frame_001367.jpg
# Detection took 30.888s for 300 object proposals
# frame_001379.jpg
# Detection took 29.947s for 300 object proposals
# frame_001391.jpg
# Detection took 30.647s for 300 object proposals
# frame_001403.jpg
# Detection took 30.355s for 300 object proposals
# frame_001415.jpg
# Detection took 30.527s for 300 object proposals
# frame_001427.jpg
# Detection took 26.776s for 256 object proposals
# frame_001439.jpg
# Detection took 30.150s for 300 object proposals
# frame_001451.jpg
# Detection took 29.800s for 300 object proposals
# frame_001463.jpg
# Detection took 30.774s for 300 object proposals
# frame_001475.jpg
# Detection took 30.413s for 300 object proposals
# frame_001487.jpg
# Detection took 30.530s for 300 object proposals
# frame_001499.jpg
# Detection took 31.017s for 300 object proposals
# frame_001511.jpg
# Detection took 30.159s for 300 object proposals
# frame_001523.jpg
# Detection took 30.296s for 300 object proposals
# frame_001535.jpg
# Detection took 30.536s for 300 object proposals
# frame_001547.jpg
# Detection took 30.287s for 300 object proposals
# frame_001559.jpg
# Detection took 30.964s for 300 object proposals
# frame_001571.jpg
# Detection took 30.159s for 300 object proposals
# frame_001583.jpg
# Detection took 30.218s for 300 object proposals
# frame_001595.jpg
# Detection took 30.161s for 300 object proposals
# frame_001607.jpg
# Detection took 30.573s for 300 object proposals
# frame_001619.jpg
# Detection took 32.545s for 300 object proposals
# frame_001631.jpg
# Detection took 33.363s for 300 object proposals
# frame_001643.jpg
# Detection took 36.467s for 300 object proposals
# frame_001655.jpg
# Detection took 36.459s for 300 object proposals
# frame_001667.jpg
# Detection took 31.634s for 300 object proposals
# frame_001679.jpg
# Detection took 30.385s for 256 object proposals
# frame_001691.jpg
# Detection took 22.765s for 208 object proposals
# frame_001703.jpg
# Detection took 17.084s for 119 object proposals
# frame_001715.jpg
# Detection took 30.646s for 300 object proposals
# frame_001727.jpg
# Detection took 31.375s for 300 object proposals
# frame_001739.jpg
# Detection took 26.402s for 300 object proposals
# frame_001751.jpg
# Detection took 25.222s for 300 object proposals
# frame_001763.jpg
# Detection took 27.379s for 300 object proposals
# frame_001775.jpg
# Detection took 23.823s for 300 object proposals
# frame_001787.jpg
# Detection took 20.636s for 300 object proposals
# frame_001799.jpg
# Detection took 25.834s for 300 object proposals
# frame_001811.jpg
# Detection took 22.945s for 300 object proposals
# frame_001823.jpg
# Detection took 27.253s for 300 object proposals
# frame_001835.jpg
# Detection took 25.038s for 300 object proposals
# frame_001847.jpg
# Detection took 27.162s for 300 object proposals
# frame_001859.jpg
# Detection took 25.151s for 300 object proposals
# frame_001871.jpg
# Detection took 27.289s for 300 object proposals
# frame_001883.jpg
# Detection took 23.662s for 300 object proposals
# frame_001895.jpg
# Detection took 26.780s for 300 object proposals
# frame_001907.jpg
# Detection took 23.206s for 300 object proposals
# frame_001919.jpg
# Detection took 20.810s for 300 object proposals
# frame_001931.jpg
# Detection took 26.746s for 300 object proposals
# frame_001943.jpg
# Detection took 25.119s for 282 object proposals
# frame_001955.jpg
# Detection took 24.477s for 300 object proposals
# frame_001967.jpg
# Detection took 25.205s for 300 object proposals
# frame_001979.jpg
# Detection took 21.189s for 300 object proposals
# frame_001991.jpg
# Detection took 26.124s for 300 object proposals
# frame_002003.jpg
# Detection took 21.189s for 300 object proposals
# frame_002015.jpg
# Detection took 25.985s for 300 object proposals
# frame_002027.jpg
# Detection took 20.065s for 300 object proposals
# frame_002039.jpg
# Detection took 27.200s for 300 object proposals
# frame_002051.jpg
# Detection took 25.385s for 300 object proposals
# frame_002063.jpg
# Detection took 26.035s for 300 object proposals
# frame_002075.jpg
# Detection took 29.097s for 300 object proposals
# frame_002087.jpg
# Detection took 25.521s for 300 object proposals
# frame_002099.jpg
# Detection took 24.394s for 300 object proposals
# frame_002111.jpg
# Detection took 23.835s for 300 object proposals
# frame_002123.jpg
# Detection took 30.095s for 300 object proposals
# frame_002135.jpg
# Detection took 26.527s for 300 object proposals
# frame_002147.jpg
